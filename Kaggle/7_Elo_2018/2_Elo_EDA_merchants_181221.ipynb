# %% [markdown]
# # ELO MERCHANT CATEGORY RECOMMENDATION
# ### COMPETITION ON KAGGLE
# ## EDA OF merchants.csv
# ### 21-12-2018

# %%
## Variables specific for competition

ID = 'card_id' 
MER_ID = 'merchant_id'
TARGET = 'target'    

RAW_DIRECTORY = 'C:/Users/judit/Documents/learning/kaggle/Elo_201812/rawdata/'  
DIRECTORY = 'C:/Users/judit/Documents/learning/kaggle/Elo_201812/data/'
HIST_TRANS_FILE = RAW_DIRECTORY + 'historical_transactions.csv'
MERCHANTS_FILE = RAW_DIRECTORY + 'merchants.csv'
NEW_MERCH_TRANS_FILE = RAW_DIRECTORY + 'new_merchant_transactions.csv'
TRAIN_FILE = RAW_DIRECTORY + 'train.csv'    
TEST_FILE = RAW_DIRECTORY +'test.csv'
SAMPLE_SUBMISSION_FILE = RAW_DIRECTORY + 'sample_submission.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import random
#import missingno
import pickle

random.seed(1)

# %%
mers = pd.read_csv(MERCHANTS_FILE)
mers.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_a70e9c5f81               5026                   792             9
# 4  M_ID_64456c37ce               2228                   222            21
#
#    numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471          N                       E
# 1    -0.057471    -0.057471          N                       E
# 2    -0.057471    -0.057471          N                       E
# 3    -0.057471    -0.057471          Y                       E
# 4    -0.057471    -0.057471          Y                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# ...

# %%
mers.shape
# Out:
# (334696, 22)

# %%
for idx in range(len(mers.columns)):
    print(mers.dtypes[idx], ' '*6, mers.columns[idx])
# Out:
# object        merchant_id
# int64        merchant_group_id
# int64        merchant_category_id
# int64        subsector_id
# float64        numerical_1
# float64        numerical_2
# object        category_1
# object        most_recent_sales_range
# object        most_recent_purchases_range
# float64        avg_sales_lag3
# float64        avg_purchases_lag3
# int64        active_months_lag3
# float64        avg_sales_lag6
# float64        avg_purchases_lag6
# int64        active_months_lag6
# float64        avg_sales_lag12
# float64        avg_purchases_lag12
# int64        active_months_lag12
# object        category_4
# int64        city_id
# int64        state_id
# float64        category_2

# %%
mers.describe()
# Out:
#        merchant_group_id  merchant_category_id   subsector_id    numerical_1  \
# count      334696.000000         334696.000000  334696.000000  334696.000000
# mean        31028.736143            423.131663      25.116404       0.011476
# std         31623.043426            252.898046       9.807371       1.098154
# min             1.000000             -1.000000      -1.000000      -0.057471
# 25%          3612.000000            222.000000      19.000000      -0.057471
# 50%         19900.000000            373.000000      27.000000      -0.057471
# 75%         51707.250000            683.000000      33.000000      -0.047556
# max        112586.000000            891.000000      41.000000     183.735111
#
#          numerical_2  avg_sales_lag3  avg_purchases_lag3  active_months_lag3  \
# count  334696.000000   334683.000000        3.346960e+05       334696.000000
# mean        0.008103       13.832993                 inf            2.994108
# ...

# %%
mers[mers['avg_sales_lag3'].isnull()]
# Out:
#         merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 3   M_ID_a70e9c5f81               5026                   792             9
# 4   M_ID_64456c37ce               2228                   222            21
# 5   M_ID_a0915f62b5              20201                    87            27
# 6   M_ID_bfd41933db              33861                   792             9
# 7   M_ID_d8ff08219e              16430                   529            20
# 8   M_ID_c5b389236d              37179                   813            29
# 9   M_ID_d2162ed113             112122                    81            29
# 10  M_ID_492cfa500c              13462                   369            27
# 11  M_ID_73487fed26              17123                   427            27
# 12  M_ID_7149162139               2118                    63            27
# 13  M_ID_a31332e0bc              15040                   427            27
# ...

# %%
mers[mers['avg_sales_lag6'].isnull()]
# Out:
#         merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 3   M_ID_a70e9c5f81               5026                   792             9
# 4   M_ID_64456c37ce               2228                   222            21
# 5   M_ID_a0915f62b5              20201                    87            27
# 6   M_ID_bfd41933db              33861                   792             9
# 7   M_ID_d8ff08219e              16430                   529            20
# 8   M_ID_c5b389236d              37179                   813            29
# 9   M_ID_d2162ed113             112122                    81            29
# 10  M_ID_492cfa500c              13462                   369            27
# 11  M_ID_73487fed26              17123                   427            27
# 12  M_ID_7149162139               2118                    63            27
# 13  M_ID_a31332e0bc              15040                   427            27
# ...

# %%
mers[mers['avg_sales_lag12'].isnull()]
# Out:
#         merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 3   M_ID_a70e9c5f81               5026                   792             9
# 4   M_ID_64456c37ce               2228                   222            21
# 5   M_ID_a0915f62b5              20201                    87            27
# 6   M_ID_bfd41933db              33861                   792             9
# 7   M_ID_d8ff08219e              16430                   529            20
# 8   M_ID_c5b389236d              37179                   813            29
# 9   M_ID_d2162ed113             112122                    81            29
# 10  M_ID_492cfa500c              13462                   369            27
# 11  M_ID_73487fed26              17123                   427            27
# 12  M_ID_7149162139               2118                    63            27
# 13  M_ID_a31332e0bc              15040                   427            27
# ...

# %%
mers[mers['category_2'].isnull()]
# Out:
#             merchant_id  merchant_group_id  merchant_category_id  \
# 3       M_ID_a70e9c5f81               5026                   792
# 4       M_ID_64456c37ce               2228                   222
# 7       M_ID_d8ff08219e              16430                   529
# 9       M_ID_d2162ed113             112122                    81
# 11      M_ID_73487fed26              17123                   427
# 15      M_ID_c9855bf3e3                321                   690
# 48      M_ID_68d5721729               5670                   178
# 52      M_ID_44384f4b59               8533                   544
# 74      M_ID_64eacbe6fd              43601                   222
# 111     M_ID_0039220eb3                 35                   836
# 112     M_ID_0039220eb3                 35                   836
# 211     M_ID_ad7402ed3c               5211                    68
# 234     M_ID_a2389b1686              70502                   222
# ...
